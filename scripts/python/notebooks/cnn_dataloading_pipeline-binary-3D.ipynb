# %%
import pandas as pd
from scipy.io import loadmat
import tables
import numpy as np
import glob
import random

# %%
"""
Author: Trevor Jordan Grant.
default4: spatial/verbal
"""
# Dictionary is labeled such that task labels in conditions files will have
# more than one multilabeling schema.

# To add more multilabeling schema - include them in the task Dictionary.
# (The sub-dictionary where the task label is the key.)

# default4 = ["VerbalWM", "SpatialWM", "VisualPerceptual", "AuditoryPerceptual"]
# every label in default 4 has discrete values of 'off', 'low', 'high'

# default3 = ["WM", "VisualPerceptual", "AuditoryPerceptual"]
# every label in default 3 has discrete values of 'off', 'low', 'high'

cog_load_label_dict = {
# Mindfulness task labels.
                       "nb": {
                              "default4": ["high", "off", "low", "off"],
                              "default3": ["high", "low", "off"],
                             },
                       "anb": {
                               "default4": ["high", "off", "off", "low"],
                               "default3": ["high", "off", "low"],
                              },
                       "ewm": {
                               "default4": ["low", "off", "high", "off"],
                               "default3": ["low", "high", "off"]
                              },
                        "cr": {
                               "default4": ["off", "off", "off", "off"],
                               "default3": ["off", "off", "off"],
                              },
                        "rt": {
                               "default4": ["off", "off", "low", "off"],
                               "default3": ["off", "low", "off"],
                              },
                        "es": {
                               "default4": ["off", "off", "low", "off"],
                               "default3": ["off", "low", "off"],
                              },
                       "gng": {
                               "default4": ["off", "off", "low", "off"],
                               "default3": ["off", "low", "off"],
                              },
            "adaptive_words": {
                               "default4": ["off", "off", "low", "off"],
                               "default3": ["off", "low", "off"],
                              },
                   "go_nogo": {
                               "default4": ["off", "off", "low", "off"],
                               "default3": ["off", "low", "off"],
                              },
                     "nback": {
                               "default4": ["high", "off", "low", "off"],
                               "default3": ["high", "low", "off"],
                              },
                    "posner": {
                               "default4": ["off", "off", "low", "off"],
                               "default3": ["off", "low", "off"],
                              },
                 "simple_rt": {
                               "default4": ["off", "off", "low", "off"],
                               "default3": ["off", "low", "off"],
                              },
             "visual_search": {
                               "default4": ["off", "off", "high", "off"],
                               "default3": ["off", "high", "off"],
                              },
                      }


def strings_to_vectors(string_labels, as_list=False):
    """Maps strings in dict to interger values.
    Args:
        string_labels(list): The string label value of load.
        as_list(bool): False, if True, return list instead of np.array()
    Returns:
        labels as np.array()
    """

    maps = {
            "off": 0,
            "low": 1,
            "high": 2,
           }

    if as_list:
        return [maps[label] for label in string_labels]
    return np.array([maps[label] for label in string_labels])


def return_label(task, label_type="default3", as_strings=False):
    """Returns a label from the cog_load_label_dict.
    Args:
        task(str): The task label from the coditions file.
        label_type(string): The label schema used for the model.
        as_strings(bool): False, if True, return string (in list) values instead.
    Returns:
        labels(np.array): Under defaults labels will be returned as interger
        values in a np.array().
    """
    if as_strings:
        return cog_load_label_dict[task][label_type]
    return strings_to_vectors(cog_load_label_dict[task][label_type])

# %%
channel_52_5x11_mat = {
           1:[0,1],  2:[0,2],  3:[0,3],  4:[0,4],  5:[0,5],  6:[0,6],  7:[0,7],  8:[0,8],  9:[0,9], 10:[0,10], 
11:[1,0], 12:[1,1], 13:[1,2], 14:[1,3], 15:[1,4], 16:[1,5], 17:[1,6], 18:[1,7], 19:[1,8], 20:[1,9], 21:[1,10], 
          22:[2,1], 23:[2,2], 24:[2,3], 25:[2,4], 26:[2,5], 27:[2,6], 28:[2,7], 29:[2,8], 30:[2,9], 31:[2,10], 
32:[3,0], 33:[3,1], 34:[3,2], 35:[3,3], 36:[3,4], 37:[3,5], 38:[3,6], 39:[3,7], 40:[3,8], 41:[3,9], 42:[3,10], 
          43:[4,1], 44:[4,2], 45:[4,3], 46:[4,4], 47:[4,5], 48:[4,6], 49:[4,7], 50:[4,8], 51:[4,9], 52:[4,10]
}

def get_52_5x11_mat(data):
    # returns a matrix of size 5x11.
    mat = np.zeros((5, 11))
    for idx, i in enumerate((data)):
        loc = channel_52_5x11_mat[idx+1]
        mat[loc[0], loc[1]] = i
    return mat

channel_52_5x22_mat = {
           1:[0,1],  2:[0,3],  3:[0,5],  4:[0,7],  5:[0,9],  6:[0,11],  7:[0,13],  8:[0,15],  9:[0,17], 10:[0,19], 
11:[1,0], 12:[1,2], 13:[1,4], 14:[1,6], 15:[1,8], 16:[1,10], 17:[1,12], 18:[1,14], 19:[1,16], 20:[1,18], 21:[1,20], 
          22:[2,1], 23:[2,3], 24:[2,5], 25:[2,7], 26:[2,9], 27:[2,11], 28:[2,13], 29:[2,15], 30:[2,17], 31:[2,19], 
32:[3,0], 33:[3,2], 34:[3,4], 35:[3,6], 36:[3,8], 37:[3,10], 38:[3,12], 39:[3,14], 40:[3,16], 41:[3,18], 42:[3,20], 
          43:[4,1], 44:[4,3], 45:[4,5], 46:[4,7], 47:[4,9], 48:[4,11], 49:[4,13], 50:[4,15], 51:[4,17], 52:[4,19]
}

def get_52_5x22_mat(data):
    # returns a matrix of size 5x11.
    mat = np.zeros((5, 22))
    for idx, i in enumerate((data)):
        loc = channel_52_5x22_mat[idx+1]
        mat[loc[0], loc[1]] = i
    return mat

# %%
def collapse_tasks(tasks, min_dur):
    collapsed_tasks = []
    collapsed_tasks.append(
        tasks[0]
    )
    for i in range(1, len(tasks)):
        t1 = collapsed_tasks[-1]
        t2 = tasks[i]
        if t1["class"] == t2["class"] and (t2["duration"] < min_dur and t1["duration"] < min_dur):
            
            t1["data"] = np.concatenate((t1["data"], t2["data"]), axis=0)
            t1["duration"]+=t2["duration"]
            t1["end"]=t1["onset"]+t2["duration"]
            # merge and append
        else:
            # just append
            collapsed_tasks.append(t2)
    return collapsed_tasks
            
def read_tasks(condition, data):
    # conditions, data = csv, mat files
    # tuple containing (class, onset, duration, offset, oxy_data, dxy_data)
    tasks = []
    # read conditions, data
    c_data = pd.read_csv(condition)
    m_data = loadmat(data)
    # get oxy, dxy data
    oxyDaya = m_data['nirs_data'][0][0][0]
    dxyData = m_data['nirs_data'][0][0][1]
    # iterate through all the tasks here now.
    for idx, key in enumerate(list(c_data.keys())):
        start = 0
        end = 0
        class_ = None
        if 'Task' in key or 'all_benchmarks_fNIRS' in key:
            # get start and end index of the task
            if 'Task' in key:
                start = int(c_data[key][0])
                duration = int(c_data[key][1])
                class_ = c_data[key][2]
            else:
                start = int(c_data[key][2])
                duration = int(c_data[key][3]) 
                class_ = c_data[key][4]
            end = start + duration
            
            # visualize heatmap: 
            # sns.heatmap(get_52_mat(oxyDaya[0]))

            oxy_series = oxyDaya[start:end, :]
            dxy_series = dxyData[start:end, :]

            # a 100x5x22 list
            oxy_dxy_series_mat = np.zeros((duration,2, 5, 11))

            for ts, (oxy_slice, dxy_slice) in enumerate(zip(oxy_series, dxy_series)):
                oxy_slice = get_52_5x11_mat(oxy_slice)
                dxy_slice = get_52_5x11_mat(dxy_slice)

                #oxy_dxy_series_mat[ts] = np.hstack([oxy_slice, dxy_slice])
                oxy_dxy_series_mat[ts] = np.array([oxy_slice, dxy_slice])
            tasks.append(
                {
                    "class": class_,
                    "onset": start,
                    "end": end,
                    "duration": duration,
                    "data" : oxy_dxy_series_mat
                }
            )
    return tasks

# %%
conditions = glob.glob('../../../data/multilabel/mats/*fNIRS_conditions_*.csv')
data = glob.glob('../../../data/multilabel/mats/*Probe1*.csv.mat')

# %%
task_data = []
time_series_length = 250
"""
default3 labels
[ 
    wm, 
    v, 
    a
]
"""

for idx, (cond, dat) in enumerate(zip(conditions, data)):
    print(dat)
    tasks = read_tasks(cond, dat)
    for t in tasks:
        task_data.append(t)
    task_data = collapse_tasks(task_data, min_dur=time_series_length)
# Out:
# ../../../data/multilabel/mats\2001_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\2002_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\2003_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\2004_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\2006_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\2007_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\2011_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\2012_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\2013_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\2014_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\2015_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\2017_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\2019_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\7102_MES_Probe1_s1.csv.mat
# ../../../data/multilabel/mats\7103_MES_Probe1_s1.csv.mat
# ../../../data/multilabel/mats\7104_MES_Probe1_s1.csv.mat
# ../../../data/multilabel/mats\7105_MES_Probe1_s1.csv.mat
# ../../../data/multilabel/mats\7107_MES_Probe1_s1.csv.mat
# ../../../data/multilabel/mats\7110_MES_Probe1_s1.csv.mat
# ../../../data/multilabel/mats\7111_MES_Probe1_s1.csv.mat
# ../../../data/multilabel/mats\7112_MES_Probe1_s1.csv.mat
# ../../../data/multilabel/mats\7113_MES_Probe1_s1.csv.mat
# ../../../data/multilabel/mats\7114_MES_Probe1_s1.csv.mat
# ../../../data/multilabel/mats\7115_MES_Probe1_s1.csv.mat
# ../../../data/multilabel/mats\7117_MES_Probe1_s1.csv.mat
# ../../../data/multilabel/mats\7120_MES_Probe1_s1.csv.mat
# ../../../data/multilabel/mats\8201_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\8202_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\8203_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\8204_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\8205_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\8206_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\8208_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\8209_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\8210_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\8211_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\8212_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\8213_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\8214_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\8215_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\8216_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\8217_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\8218_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\8219_MES_Probe1.csv.mat
# ../../../data/multilabel/mats\8220_MES_Probe1.csv.mat

# %%
labels_bin = {"wm":{0:0, 1:0, 2:0}, "vl":{0:0, 1:0, 2:0}, "al":{0:0, 1:0, 2:0}}
task_cond_bin = {i:{"ts":0, "cnt":0} for i in cog_load_label_dict}
for t in task_data:
    label = return_label(t["class"])
    
    task_cond_bin[t["class"]]["cnt"]+=1
    task_cond_bin[t["class"]]["ts"] = max(task_cond_bin[t["class"]]["ts"], t["duration"])
    
    labels_bin["wm"][label[0]]+=1
    labels_bin["vl"][label[1]]+=1
    labels_bin["al"][label[2]]+=1

# %%
print(task_cond_bin, labels_bin)
# Out:
# {'go_nogo': {'cnt': 182, 'ts': 320}, 'nb': {'cnt': 64, 'ts': 900}, 'anb': {'cnt': 64, 'ts': 1000}, 'nback': {'cnt': 428, 'ts': 320}, 'simple_rt': {'cnt': 39, 'ts': 320}, 'cr': {'cnt': 384, 'ts': 250}, 'rt': {'cnt': 64, 'ts': 650}, 'gng': {'cnt': 64, 'ts': 850}, 'visual_search': {'cnt': 168, 'ts': 320}, 'posner': {'cnt': 182, 'ts': 320}, 'es': {'cnt': 64, 'ts': 700}, 'adaptive_words': {'cnt': 112, 'ts': 320}, 'ewm': {'cnt': 64, 'ts': 3000}} {'vl': {0: 448, 1: 1199, 2: 232}, 'wm': {0: 1259, 1: 64, 2: 556}, 'al': {0: 1815, 1: 64, 2: 0}}

# %%
"""
    write data to disk
"""
random.shuffle(task_data)
for idx, data in enumerate(task_data[0:]):
    print(data["class"])
    oxy_dxy_data = np.zeros((time_series_length, 2, 5, 11))
    data_len = data["data"].shape[0]
    oxy_dxy_data[:min(data_len, time_series_length)] = data["data"][:min(data_len, time_series_length)]
    
    if data["class"] == "cr":
        np.save("C:\\Users\\dhruv\\Development\\git\\thesis_dl-fnirs\\data\\binary\\3D\\val\\" + str(idx), np.asarray([oxy_dxy_data, 0]))
    else:
        np.save("C:\\Users\\dhruv\\Development\\git\\thesis_dl-fnirs\\data\\binary\\3D\\train\\" + str(idx), np.asarray([oxy_dxy_data, 1]))
# Out:
# nback
# go_nogo
# visual_search
# nback
# visual_search
# adaptive_words
# nback
# cr
# nback
# cr
# rt
# rt
# visual_search
# go_nogo
# visual_search
# visual_search
# ewm
# nback
# nback
# posner
# posner
# nback
# cr
# adaptive_words
# go_nogo
# posner
# cr
# nback
# cr
# go_nogo
# adaptive_words
# ewm
# ewm
# cr
# posner
# cr
# nback
# nback
# cr
# posner
# nback
# rt
# simple_rt
# go_nogo
# posner
# go_nogo
# cr
# visual_search
# es
# visual_search
# gng
# rt
# nback
# cr
# nback
# nback
# go_nogo
# ewm
# cr
# go_nogo
# anb
# rt
# nback
# anb
# cr
# gng
# cr
# cr
# adaptive_words
# nback
# cr
# cr
# visual_search
# cr
# nb
# cr
# gng
# rt
# nback
# anb
# ewm
# cr
# cr
# go_nogo
# nback
# anb
# adaptive_words
# go_nogo
# go_nogo
# ewm
# nback
# cr
# cr
# nback
# posner
# visual_search
# gng
# cr
# posner
# rt
# cr
# nback
# posner
# cr
# cr
# visual_search
# visual_search
# adaptive_words
# posner
# cr
# nback
# nback
# cr
# cr
# visual_search
# visual_search
# visual_search
# visual_search
# adaptive_words
# adaptive_words
# nback
# go_nogo
# nback
# nback
# nback
# go_nogo
# nback
# cr
# go_nogo
# es
# cr
# nback
# adaptive_words
# visual_search
# cr
# nback
# ewm
# adaptive_words
# gng
# cr
# cr
# nback
# cr
# posner
# posner
# cr
# nback
# adaptive_words
# rt
# nb
# cr
# posner
# posner
# cr
# go_nogo
# gng
# adaptive_words
# go_nogo
# gng
# es
# nback
# gng
# cr
# posner
# posner
# cr
# adaptive_words
# go_nogo
# adaptive_words
# anb
# posner
# cr
# cr
# nback
# nback
# adaptive_words
# go_nogo
# posner
# rt
# anb
# posner
# cr
# cr
# nb
# rt
# nback
# go_nogo
# rt
# cr
# cr
# go_nogo
# simple_rt
# rt
# ewm
# posner
# nback
# nback
# adaptive_words
# nback
# es
# anb
# nback
# nb
# cr
# nback
# cr
# posner
# rt
# gng
# nback
# cr
# posner
# nback
# nback
# cr
# gng
# cr
# visual_search
# es
# posner
# nback
# go_nogo
# cr
# cr
# cr
# go_nogo
# nback
# adaptive_words
# go_nogo
# es
# visual_search
# nback
# visual_search
# nback
# nback
# nback
# simple_rt
# posner
# nback
# adaptive_words
# ewm
# cr
# cr
# adaptive_words
# nb
# cr
# rt
# simple_rt
# cr
# nb
# rt
# adaptive_words
# visual_search
# ewm
# cr
# ewm
# posner
# gng
# nback
# nback
# nback
# nb
# cr
# cr
# visual_search
# es
# anb
# nback
# ewm
# ewm
# posner
# cr
# nback
# nb
# gng
# cr
# gng
# ewm
# gng
# visual_search
# nback
# go_nogo
# posner
# nback
# posner
# cr
# rt
# nback
# go_nogo
# posner
# go_nogo
# ewm
# anb
# cr
# rt
# adaptive_words
# cr
# rt
# go_nogo
# anb
# posner
# nback
# cr
# cr
# cr
# visual_search
# nback
# cr
# nback
# visual_search
# posner
# cr
# go_nogo
# cr
# visual_search
# go_nogo
# nback
# cr
# nb
# ewm
# nback
# cr
# nb
# adaptive_words
# cr
# ewm
# nback
# nback
# nback
# go_nogo
# cr
# posner
# cr
# go_nogo
# visual_search
# cr
# visual_search
# nback
# ewm
# simple_rt
# go_nogo
# posner
# posner
# simple_rt
# cr
# nback
# posner
# cr
# visual_search
# cr
# nback
# nb
# cr
# go_nogo
# ewm
# go_nogo
# posner
# nback
# cr
# posner
# adaptive_words
# nback
# nback
# adaptive_words
# visual_search
# go_nogo
# nb
# adaptive_words
# posner
# visual_search
# cr
# go_nogo
# nb
# simple_rt
# es
# nback
# visual_search
# nback
# go_nogo
# posner
# nback
# gng
# adaptive_words
# rt
# nback
# posner
# anb
# nback
# go_nogo
# nback
# visual_search
# cr
# cr
# cr
# cr
# anb
# go_nogo
# posner
# nb
# nback
# nback
# es
# nback
# anb
# adaptive_words
# es
# nb
# gng
# cr
# go_nogo
# posner
# adaptive_words
# cr
# adaptive_words
# nback
# rt
# cr
# cr
# go_nogo
# nback
# adaptive_words
# cr
# posner
# es
# posner
# ewm
# nback
# go_nogo
# es
# posner
# cr
# gng
# cr
# rt
# nback
# cr
# adaptive_words
# cr
# adaptive_words
# go_nogo
# posner
# nback
# gng
# anb
# nback
# nback
# anb
# visual_search
# go_nogo
# cr
# nback
# cr
# cr
# nback
# go_nogo
# nback
# nback
# gng
# go_nogo
# posner
# gng
# es
# go_nogo
# cr
# nback
# go_nogo
# go_nogo
# nback
# rt
# visual_search
# simple_rt
# nback
# nback
# cr
# posner
# cr
# nback
# anb
# anb
# cr
# cr
# gng
# rt
# rt
# nback
# visual_search
# go_nogo
# nback
# posner
# simple_rt
# es
# es
# nback
# nback
# es
# es
# visual_search
# posner
# nb
# nb
# cr
# nback
# adaptive_words
# nback
# go_nogo
# ewm
# cr
# go_nogo
# adaptive_words
# cr
# es
# go_nogo
# ewm
# nback
# anb
# cr
# cr
# visual_search
# gng
# nback
# visual_search
# anb
# anb
# nback
# nb
# simple_rt
# cr
# anb
# ewm
# nback
# gng
# adaptive_words
# go_nogo
# visual_search
# visual_search
# nback
# cr
# nback
# go_nogo
# posner
# cr
# rt
# visual_search
# adaptive_words
# rt
# nback
# es
# simple_rt
# posner
# posner
# go_nogo
# gng
# cr
# cr
# cr
# nback
# nb
# nback
# posner
# nback
# go_nogo
# nback
# posner
# cr
# rt
# cr
# es
# posner
# adaptive_words
# anb
# go_nogo
# nback
# cr
# go_nogo
# anb
# visual_search
# visual_search
# cr
# nb
# ewm
# gng
# adaptive_words
# visual_search
# cr
# posner
# cr
# cr
# adaptive_words
# es
# visual_search
# cr
# posner
# posner
# cr
# cr
# go_nogo
# nback
# cr
# simple_rt
# go_nogo
# nback
# cr
# nback
# cr
# visual_search
# posner
# gng
# cr
# simple_rt
# nback
# adaptive_words
# nb
# nb
# nb
# nback
# anb
# go_nogo
# nback
# gng
# simple_rt
# cr
# posner
# go_nogo
# posner
# cr
# adaptive_words
# nback
# nback
# nback
# rt
# visual_search
# anb
# cr
# visual_search
# posner
# go_nogo
# adaptive_words
# anb
# go_nogo
# adaptive_words
# nback
# es
# nback
# es
# cr
# nback
# visual_search
# nback
# nb
# cr
# adaptive_words
# nback
# cr
# nback
# cr
# posner
# nback
# gng
# go_nogo
# cr
# nback
# simple_rt
# nback
# cr
# nb
# posner
# nb
# nback
# adaptive_words
# cr
# go_nogo
# nback
# go_nogo
# nb
# nback
# visual_search
# cr
# nback
# nback
# nback
# nback
# nb
# posner
# anb
# cr
# nb
# nback
# posner
# cr
# go_nogo
# posner
# cr
# cr
# nback
# gng
# ewm
# cr
# nback
# visual_search
# es
# cr
# nback
# nback
# go_nogo
# gng
# nback
# nback
# go_nogo
# cr
# posner
# nback
# adaptive_words
# anb
# go_nogo
# nback
# go_nogo
# nback
# go_nogo
# adaptive_words
# posner
# adaptive_words
# nback
# nback
# visual_search
# visual_search
# cr
# cr
# nback
# nback
# visual_search
# cr
# visual_search
# nback
# posner
# nback
# cr
# go_nogo
# nb
# nb
# anb
# cr
# cr
# rt
# nback
# ewm
# cr
# simple_rt
# cr
# cr
# nback
# es
# anb
# go_nogo
# visual_search
# nback
# es
# nback
# nb
# gng
# es
# adaptive_words
# rt
# nback
# visual_search
# go_nogo
# cr
# posner
# cr
# go_nogo
# cr
# nback
# posner
# nback
# nback
# posner
# anb
# ewm
# nb
# posner
# go_nogo
# anb
# adaptive_words
# go_nogo
# ewm
# cr
# cr
# visual_search
# cr
# nback
# go_nogo
# nback
# nback
# go_nogo
# ewm
# posner
# nback
# visual_search
# posner
# nback
# nback
# nback
# nback
# posner
# rt
# cr
# cr
# cr
# visual_search
# es
# anb
# nb
# nback
# visual_search
# posner
# posner
# nback
# nb
# nback
# nback
# nback
# cr
# visual_search
# cr
# rt
# gng
# nback
# nback
# cr
# cr
# cr
# nback
# cr
# nback
# cr
# simple_rt
# nback
# nback
# nback
# cr
# nback
# cr
# cr
# gng
# posner
# visual_search
# nback
# posner
# anb
# nback
# posner
# nback
# posner
# cr
# cr
# cr
# anb
# nback
# posner
# cr
# cr
# adaptive_words
# cr
# go_nogo
# nb
# visual_search
# go_nogo
# rt
# adaptive_words
# anb
# cr
# adaptive_words
# nback
# cr
# visual_search
# cr
# posner
# cr
# nback
# visual_search
# go_nogo
# es
# es
# rt
# cr
# nback
# nback
# nback
# visual_search
# posner
# posner
# go_nogo
# gng
# gng
# adaptive_words
# visual_search
# ewm
# posner
# nback
# simple_rt
# cr
# cr
# cr
# anb
# visual_search
# cr
# nback
# adaptive_words
# es
# nback
# nb
# visual_search
# go_nogo
# cr
# anb
# nback
# cr
# nback
# posner
# cr
# go_nogo
# adaptive_words
# ewm
# go_nogo
# nback
# cr
# nback
# simple_rt
# anb
# rt
# posner
# cr
# simple_rt
# cr
# nback
# cr
# nback
# go_nogo
# nback
# posner
# cr
# cr
# posner
# go_nogo
# cr
# ewm
# posner
# simple_rt
# cr
# nback
# visual_search
# nback
# go_nogo
# nback
# simple_rt
# posner
# nback
# posner
# nback
# posner
# nback
# rt
# nback
# cr
# cr
# cr
# nback
# nback
# cr
# nback
# cr
# cr
# go_nogo
# go_nogo
# adaptive_words
# nback
# posner
# cr
# visual_search
# posner
# ewm
# adaptive_words
# go_nogo
# adaptive_words
# nback
# nback
# cr
# rt
# go_nogo
# cr
# adaptive_words
# visual_search
# cr
# posner
# nback
# nback
# go_nogo
# simple_rt
# visual_search
# nback
# posner
# posner
# es
# nback
# nb
# anb
# simple_rt
# nback
# visual_search
# ewm
# go_nogo
# es
# adaptive_words
# simple_rt
# visual_search
# anb
# posner
# cr
# nback
# visual_search
# ewm
# rt
# cr
# nback
# anb
# posner
# cr
# go_nogo
# nb
# cr
# cr
# go_nogo
# cr
# adaptive_words
# posner
# visual_search
# visual_search
# posner
# posner
# adaptive_words
# anb
# ewm
# es
# gng
# visual_search
# go_nogo
# cr
# go_nogo
# nback
# go_nogo
# adaptive_words
# visual_search
# nback
# visual_search
# ewm
# nback
# adaptive_words
# gng
# visual_search
# cr
# cr
# adaptive_words
# posner
# cr
# visual_search
# adaptive_words
# visual_search
# ewm
# cr
# go_nogo
# nb
# go_nogo
# es
# cr
# cr
# posner
# nback
# visual_search
# go_nogo
# es
# nb
# gng
# nback
# posner
# go_nogo
# posner
# nback
# posner
# adaptive_words
# rt
# visual_search
# adaptive_words
# nback
# cr
# cr
# adaptive_words
# posner
# nback
# nback
# visual_search
# anb
# nback
# nback
# go_nogo
# visual_search
# nback
# posner
# nback
# posner
# adaptive_words
# go_nogo
# gng
# adaptive_words
# posner
# posner
# posner
# nback
# posner
# visual_search
# nback
# nback
# posner
# gng
# nback
# es
# cr
# nback
# anb
# cr
# go_nogo
# nback
# nback
# visual_search
# visual_search
# go_nogo
# nback
# anb
# visual_search
# visual_search
# posner
# cr
# cr
# rt
# nback
# visual_search
# gng
# rt
# nback
# go_nogo
# visual_search
# anb
# cr
# gng
# posner
# cr
# nb
# cr
# posner
# go_nogo
# nback
# nback
# anb
# nback
# visual_search
# cr
# nback
# nback
# posner
# nback
# cr
# ewm
# ewm
# cr
# rt
# cr
# cr
# nback
# visual_search
# nback
# cr
# nb
# go_nogo
# nback
# nback
# cr
# nback
# adaptive_words
# posner
# cr
# es
# nb
# adaptive_words
# visual_search
# nback
# posner
# nback
# cr
# nback
# visual_search
# es
# go_nogo
# visual_search
# ewm
# nback
# rt
# rt
# adaptive_words
# cr
# cr
# anb
# cr
# posner
# cr
# go_nogo
# nback
# rt
# posner
# posner
# go_nogo
# anb
# es
# nback
# posner
# cr
# posner
# simple_rt
# simple_rt
# cr
# nb
# adaptive_words
# anb
# visual_search
# cr
# cr
# cr
# nback
# posner
# cr
# visual_search
# nback
# nback
# es
# go_nogo
# go_nogo
# posner
# adaptive_words
# cr
# es
# cr
# posner
# cr
# cr
# es
# nback
# nback
# visual_search
# nb
# nback
# adaptive_words
# nback
# go_nogo
# cr
# nback
# adaptive_words
# cr
# nback
# nb
# cr
# visual_search
# posner
# nback
# adaptive_words
# nback
# gng
# nback
# ewm
# cr
# posner
# nb
# gng
# es
# nback
# nback
# cr
# cr
# nback
# anb
# cr
# nback
# visual_search
# visual_search
# go_nogo
# adaptive_words
# simple_rt
# cr
# gng
# go_nogo
# nback
# posner
# nback
# nback
# nback
# posner
# go_nogo
# nback
# ewm
# posner
# nback
# es
# cr
# nback
# cr
# cr
# cr
# nback
# nback
# gng
# go_nogo
# simple_rt
# go_nogo
# visual_search
# cr
# nback
# cr
# es
# visual_search
# nback
# posner
# nb
# go_nogo
# nback
# posner
# adaptive_words
# posner
# posner
# cr
# go_nogo
# simple_rt
# rt
# go_nogo
# go_nogo
# cr
# cr
# posner
# visual_search
# es
# nback
# visual_search
# cr
# cr
# es
# go_nogo
# cr
# nback
# nback
# nback
# cr
# cr
# cr
# gng
# visual_search
# gng
# nback
# ewm
# nb
# nback
# go_nogo
# nback
# cr
# es
# ewm
# nback
# posner
# adaptive_words
# adaptive_words
# go_nogo
# cr
# ewm
# rt
# cr
# adaptive_words
# nback
# visual_search
# go_nogo
# go_nogo
# rt
# simple_rt
# gng
# nback
# rt
# posner
# rt
# visual_search
# nback
# gng
# go_nogo
# visual_search
# simple_rt
# nback
# posner
# es
# posner
# cr
# go_nogo
# visual_search
# es
# cr
# es
# go_nogo
# ewm
# rt
# es
# nback
# anb
# go_nogo
# cr
# cr
# posner
# anb
# visual_search
# nback
# go_nogo
# cr
# rt
# cr
# nback
# cr
# visual_search
# nback
# posner
# anb
# go_nogo
# nback
# nback
# posner
# visual_search
# es
# visual_search
# ewm
# cr
# nback
# rt
# nback
# nback
# visual_search
# go_nogo
# go_nogo
# simple_rt
# nback
# visual_search
# posner
# go_nogo
# nback
# posner
# nback
# rt
# nback
# es
# nback
# anb
# adaptive_words
# ewm
# nback
# posner
# nback
# go_nogo
# cr
# posner
# go_nogo
# cr
# nback
# posner
# nback
# posner
# visual_search
# nback
# cr
# visual_search
# nback
# nb
# posner
# nback
# posner
# nback
# cr
# cr
# posner
# anb
# posner
# cr
# go_nogo
# go_nogo
# visual_search
# posner
# nback
# posner
# nback
# visual_search
# adaptive_words
# cr
# cr
# nback
# ewm
# ewm
# gng
# nback
# cr
# adaptive_words
# cr
# es
# nback
# gng
# go_nogo
# nb
# cr
# visual_search
# cr
# nback
# es
# cr
# rt
# cr
# cr
# go_nogo
# cr
# adaptive_words
# cr
# cr
# nback
# cr
# nback
# cr
# cr
# posner
# cr
# visual_search
# cr
# adaptive_words
# es
# nback
# nback
# nback
# nb
# ewm
# es
# nback
# simple_rt
# cr
# cr
# nback
# nback
# gng
# visual_search
# nb
# posner
# cr
# es
# visual_search
# nback
# anb
# nback
# gng
# nback
# nback
# cr
# nback
# ewm
# nback
# go_nogo
# cr
# nback
# cr
# ewm
# nback
# gng
# cr
# nback
# nback
# cr
# adaptive_words
# anb
# go_nogo
# nback
# visual_search
# adaptive_words
# ewm
# posner
# nb
# visual_search
# ewm
# visual_search
# posner
# visual_search
# cr
# nback
# cr
# cr
# nback
# nback
# nback
# simple_rt
# nback
# cr
# nback
# nback
# nback
# go_nogo
# cr
# cr
# adaptive_words
# nback
# rt
# cr
# nback
# go_nogo
# nback
# cr
# visual_search
# nback
# nback
# anb
# posner
# cr
# nback
# adaptive_words
# simple_rt
# posner
# go_nogo
# go_nogo
# nback
# rt
# nback
# cr
# adaptive_words
# nb
# nback
# rt
# adaptive_words
# cr
# ewm
# nb
# nback
# cr
# visual_search
# nback
# anb
# anb
# simple_rt
# cr
# adaptive_words
# adaptive_words
# posner
# nback
# visual_search
# nback
# cr
# rt
# nback
# nback
# nback
# nback
# go_nogo
# gng
# nback
# nback
# gng
# go_nogo
# visual_search
# cr
# visual_search
# visual_search
# go_nogo
# gng
# go_nogo
# cr
# visual_search
# cr
# adaptive_words
# posner
# go_nogo
# anb
# nb
# nback
# visual_search
# go_nogo
# go_nogo
# cr
# cr
# visual_search
# visual_search
# nback
# go_nogo
# visual_search
# adaptive_words
# cr
# ewm
# nback
# nback
# cr
# adaptive_words
# go_nogo
# rt
# go_nogo
# cr
# nback
# nback
# cr
# nback
# cr
# nback
# go_nogo
# visual_search
# go_nogo
# visual_search
# nback
# cr
# adaptive_words
# es
# nback
# nback
# adaptive_words
# nback
# cr
# adaptive_words
# cr
# cr
# cr
# gng
# adaptive_words
# visual_search
# ewm
# posner
# visual_search
# simple_rt
# cr
# cr
# visual_search
# nback
# cr
# nback
# adaptive_words
# go_nogo
# adaptive_words
# go_nogo
# nback
# cr
# go_nogo
# go_nogo
# cr
# go_nogo
# go_nogo
# cr
# rt
# nback
# nback
# posner
# visual_search
# go_nogo
# nb
# nback
# nb
# posner
# rt
# cr
# posner
# visual_search
# nback
# nback
# cr
# posner
# nback
# cr
# go_nogo
# visual_search
# nback
# nback
# adaptive_words
# visual_search
# gng
# adaptive_words
# cr
# nback
# ewm
# nback
# visual_search
# nback
# nback
# cr
# ewm
# nback
# es
# cr
# go_nogo
# visual_search
# nback
# cr
# visual_search
# visual_search
# nback
# cr
# nback
# cr
# cr
# visual_search
# go_nogo
# visual_search
# visual_search
# go_nogo
# gng
# posner
# go_nogo
# cr
# ewm
# go_nogo
# nback
# rt
# go_nogo
# cr
# nback
# cr
# visual_search
# cr
# cr
# visual_search
# ewm
# nback
# es
# visual_search
# cr
# go_nogo
# nb
# nback
# cr
# visual_search
# cr
# cr
# nback
# anb
# nb
# ewm
# nback
# cr
# nback
# cr
# nback
# nback
# visual_search
# nback
# nback
# nback
# cr
# posner
# es
# rt
# cr
# adaptive_words
# gng
# nback
# nback
# cr
# visual_search
# nback
# cr
# simple_rt
# nback
# gng
# posner
# nb
# cr
# posner
# nb
# gng
# posner
# cr
# visual_search
# adaptive_words
# nback
# adaptive_words
# posner
# nback

# %%
task_data[1]["data"].shape
# Out:
# (320, 2, 5, 11)

# %%
import seaborn as sns;
sns.set();
import matplotlib.pyplot as plt

# %%
cond_1 = 14
cond_2 = 10

oxy_1 = [i[0, 1, 1] for i in task_data[cond_1]["data"]]
dxy_1 = [i[1, 1, 1] for i in task_data[cond_1]["data"]]

oxy_2 = [i[0, 1, 1] for i in task_data[cond_2]["data"]]
dxy_2 = [i[1, 1, 1] for i in task_data[cond_2]["data"]]

df = pd.DataFrame.from_dict({
    task_data[cond_2]["class"]+"-oxy": oxy_1,
    task_data[cond_2]["class"]+"-dxy": dxy_1
})

plt.figure(figsize=(19, 9))
ax = sns.lineplot(data=df)

# %%
y.shape
# Out:
# (250, 2)
